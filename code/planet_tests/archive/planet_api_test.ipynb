# %%
# importing os module to source env variables  
import os 

# import helper functions to make Basic request to Planet API
import requests
from requests.auth import HTTPBasicAuth

base_url = 'https://tiles{0-3}.planet.com/data/v1/{item_type}/{item_id}/{z}/{x}/{y}.png'

# %%
# Get the list of user's 
env_var = os.environ 

# get home variable
home = os.environ['HOME']

# %%
  
# Print the list of user's 
print("User's home variable:", home)
# Out:
# User's home variable: /Users/jpcohen

# %%
# planet key = ....
# removed planet key. was right here, re-add it from the config file if you want to get this notebook working again 

# pass it to a variable
planet_key = os.environ["planet_api_key"]

# print it
print(f"Planet API key: {planet_key}")
# Out:
# Planet API key: PLAK723f32b266fa484cb256071a3006e80b

# %%
# authorize something idk
auth = HTTPBasicAuth(planet_key, '')

# %%
test_res = requests.get(url= "https://tiles1.planet.com/data/v1/PSScene/20161221_024131_0e19/14/12915/8124.png?api_key={PLAK723f32b266fa484cb256071a3006e80b}", auth = auth)

# %%
# make request
res = requests.get(url=base_url, auth=auth, item_id = "20230513_175130_79_24c3")

# did it work?
print(res.status_code)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # make request
# ----> 2 res = requests.get(url=base_url, auth=auth, item_id = "20230513_175130_79_24c3")
#       4 # did it work?
#       5 print(res.status_code)
#
# File ~/.conda/envs/wildfire_prep/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/.conda/envs/wildfire_prep/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
# ...
