# %%
import os
import sys
import numpy as np
import pandas as pd
import geopandas as gpd

sys.path.append("../utils")

import config

pd.set_option("display.max_columns", None)

# %%
insp_2019 = gpd.read_file(
    "/capstone/wildfire_prep/data/buffer_geometries/buffer_geometries_2019.geojson"
)
insp_2020 = gpd.read_file(
    "/capstone/wildfire_prep/data/buffer_geometries/buffer_geometries_2020.geojson"
)
insp_2021 = gpd.read_file(
    "/capstone/wildfire_prep/data/buffer_geometries/buffer_geometries_2021.geojson"
)
insp_2022 = gpd.read_file(
    "/capstone/wildfire_prep/data/buffer_geometries/buffer_geometries_2022.geojson"
)
insp_2023 = gpd.read_file(
    "/capstone/wildfire_prep/data/buffer_geometries/buffer_geometries_2023.geojson"
)

# %%
needed_columns = [
    "system_cre",
    "status",
    "latitude",
    "longitude",
    "address_su",
    "address_th",
    "address__1",
    "address_lo",
    "address__2",
    "address_ad",
    "address_po",
    "address_co",
    "address_fu",
    "Date",
    "geometry",
    "inspection",
    "structuret",
]
needed_columns_23 = [
    "updated_at",
    "status",
    "latitude",
    "longitude",
    "address_sub_thoroughfare",
    "address_thoroughfare",
    "address_suite",
    "address_locality",
    "address_sub_admin_area",
    "address_admin_area",
    "address_postal_code",
    "address_country",
    "address_full",
    "Date",
    "geometry",
    "inspectiondate_calculate",
    "structuretype",
]

# %%
insp_19_clean = insp_2019[needed_columns]
insp_20_clean = insp_2020[needed_columns]
insp_21_clean = insp_2021[needed_columns]
insp_22_clean = insp_2022[needed_columns]
insp_23_clean = insp_2023[needed_columns_23]
