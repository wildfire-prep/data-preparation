# %%
import os
import sys
import numpy as np
import pandas as pd
import geopandas as gpd

sys.path.append("../utils")

import config

pd.set_option("display.max_columns", None)

# %%
# Loading in inspections data with newly calculated geometries 4/29/25

insp_19 = gpd.read_file(
    "/capstone/wildfire_prep/data/buffer_geometries/buffer_geometries_2019.geojson"
)
insp_20 = gpd.read_file(
    "/capstone/wildfire_prep/data/buffer_geometries/buffer_geometries_2020.geojson"
)
insp_21 = gpd.read_file(
    "/capstone/wildfire_prep/data/buffer_geometries/buffer_geometries_2021.geojson"
)
insp_22 = gpd.read_file(
    "/capstone/wildfire_prep/data/buffer_geometries/buffer_geometries_2022.geojson"
)
insp_23 = gpd.read_file(
    "/capstone/wildfire_prep/data/buffer_geometries/buffer_geometries_2023.geojson"
)

# %%
rows19 = len(insp_19)
rows20 = len(insp_20)
rows21 = len(insp_21)
rows22 = len(insp_22)
rows23 = len(insp_23)

buffer_geometries_length = rows19 + rows20 + rows21 + rows22 + rows23
print(buffer_geometries_length)
# Out:
# 89357

# %%
insp_19.head()
# Out:
#                              fulcrum_id          created_at  \
# 0  d9a4d031-d16d-4c84-b32c-f3fcd7d945df 2018-05-25 16:25:06
# 1  7f9b6d98-548d-4b94-97c6-82cbddf84d99 2018-05-25 16:25:10
# 2  03afdf39-173a-4f02-bfdc-e0725e554959 2018-05-25 16:25:11
# 3  941e29b0-6cd3-4c7e-a919-b8f2410b4a2b 2018-05-25 16:25:11
# 4  abe890ba-3269-4ef6-84d7-4a9b6bfd717e 2018-05-25 16:25:11
#
#            updated_at          system_cre          system_upd  version  \
# 0 2019-06-05 11:57:49 2019-05-07 11:52:36 2019-06-05 16:35:26      2.0
# 1 2019-05-15 12:26:44 2019-05-07 11:52:37 2019-05-15 12:26:45      3.0
# 2 2019-05-09 14:20:04 2019-05-07 11:52:37 2019-05-09 15:26:24      2.0
# 3 2019-05-09 14:25:18 2019-05-07 11:52:38 2019-05-09 15:26:26      2.0
# 4 2019-12-17 14:16:14 2019-05-07 11:52:38 2019-12-18 11:43:23      5.0
#
#       status project assigned_t   latitude   longitude  \
# 0  Compliant    None       None  34.669616 -120.031160
# 1  Compliant    None       None  34.679129 -120.091914
# 2  Compliant    None       None  34.676197 -120.089553
# 3  Compliant    None       None  34.677982 -120.088944
# 4  Compliant    None       None  34.678469 -120.087539
#
#                            report_tit globalid calculated inspectorp  \
# 0  Defensible Space Inspection Report     None       None        DSI
# 1  Defensible Space Inspection Report     None       None        DSI
# 2  Defensible Space Inspection Report     None       None        DSI
# 3  Defensible Space Inspection Report     None       None        DSI
# 4  Defensible Space Inspection Report     None       None        DSI
#
#    inspection                addressvis address_su       address_th  \
# 0  2019-06-05  Yes - Without Reflective       3462   Brinkerhoff Rd
# 1  2019-05-09  Yes - Without Reflective       3290  Avenida Caballo
# 2  2019-05-09  Yes - Without Reflective       3350       Caballo Ln
# 3  2019-05-09  Yes - Without Reflective       3350       Caballo Ln
# 4  2019-12-17  Yes - Without Reflective     3320 A   Canada Este Rd
#
#   address__1  address_lo     address__2 address_ad address_po address_co  \
# 0       None  Santa Ynez  Santa Barbara         CA      93460         US
# 1       None  Santa Ynez  Santa Barbara         CA      93460         US
# 2       None  Santa Ynez  Santa Barbara         CA      93460         US
# 3       None  Santa Ynez  Santa Barbara         CA      93460         US
# 4       None  Santa Ynez  Santa Barbara         CA      93460         US
#
#                                           address_fu calfireuni county  \
# 0  3462 Brinkerhoff Rd Santa Ynez Santa Barbara C...        SBC    SBA
# 1  3290 Avenida Caballo Santa Ynez Santa Barbara ...        SBC    SBA
# 2  3350 Caballo Ln Santa Ynez Santa Barbara CA 93...        SBC    SBA
# 3  3350 Caballo Ln Santa Ynez Santa Barbara CA 93...        SBC    SBA
# 4  3320 A Canada Este Rd Santa Ynez Santa Barbara...        SBC    SBA
#
#    community community_ battalion enginenumb  \
# 0  Woodstock       None         2         32
# 1  Woodstock       None         2         32
# 2  Woodstock       None         2         32
# 3  Woodstock       None         2         32
# 4  Woodstock       None         2         32
#
#                                     stationnam stationn_1 shift occupantho  \
# 0                                           32       None  None        Yes
# 1  Santa Ynez Valley (Outside Engine Co. Area)       None  None         No
# 2  Santa Ynez Valley (Outside Engine Co. Area)       None  None         No
# 3  Santa Ynez Valley (Outside Engine Co. Area)       None  None        Yes
# 4  Santa Ynez Valley (Outside Engine Co. Area)       None  None         No
#
#   deliveryno inspecti_1 a_removebr b_removele c_removede d_removede  \
# 0   Hardcopy     30 min       None       None       None       None
# 1      Email     15 min       None       None       None       None
# 2      Email     15 min       None       None       None       None
# 3      Email     15 min       None       None       None       None
# 4   Hardcopy      5 min       None       None       None       None
#
#   e_removedy f_removefl g_relocate h_cutannua i_reducefu j_allexpos  \
# 0       None       None       None       None       None       None
# 1       None       None       None       None       None       None
# 2       None       None       None       None       None       None
# 3       None       None       None       None       None       None
# 4       None       None       None       None       None       None
#
#   k_deaddyin l_logsstum m_outbuild n_addressd o_chimneys recommend_  \
# 0       None       None       None       None       None       None
# 1       None       None       None       None       None       None
# 2       None       None       None       None       None       None
# 3       None       None       None       None       None       None
# 4       None       None       None       None       None       None
#
#        propanetan accessegre waterstora  \
# 0            >30'        yes        yes
# 1  Not Applicable        yes        yes
# 2  Not Applicable        yes       None
# 3  Not Applicable        yes         no
# 4            >30'        yes        yes
#
#                               water_sour can_engine         water_stor  \
# 0  Private Hydrant- Private Stored Water        yes  Over 5000 gallons
# 1  Private Hydrant- Private Stored Water        yes               None
# 2                                   None       None               None
# 3                                   None       None               None
# 4                                   Pond       None               None
#
#   water_comm                                     structuret roofconstr  \
# 0       None  Utility or Miscellaneous Structure > 120 sqft      Metal
# 1       None            Single Family Residence Multi Story      Metal
# 2       None            Single Family Residence Multi Story       Tile
# 3       None  Utility or Miscellaneous Structure > 120 sqft      Metal
# 4       None            Single Family Residence Multi Story    Asphalt
#
#         eaves           ventscreen           exteriorsi   windowpane  \
# 0  Unenclosed             No Vents                 Wood   No Windows
# 1    No Eaves             No Vents                 Wood  Single Pane
# 2  Unenclosed             No Vents  Stucco/Brick/Cement   Multi Pane
# 3  Unenclosed             No Vents                Metal  Single Pane
# 4  Unenclosed  Mesh Screen  > 1/8"                 Wood  Single Pane
#
#          deckporchg     deckporche              patiocover fenceattac  \
# 0     No Deck/Porch  No Deck/Porch  No Patio Cover/Carport   No Fence
# 1     No Deck/Porch  No Deck/Porch  No Patio Cover/Carport   No Fence
# 2     No Deck/Porch  No Deck/Porch  No Patio Cover/Carport   No Fence
# 3  Masonry/Concrete  No Deck/Porch  No Patio Cover/Carport   No Fence
# 4  Masonry/Concrete  No Deck/Porch         Non Combustible   No Fence
#
#   utilitymis utilitym_1 nonhabitab escalateto reinspecti clearreins  \
# 0     30-50'          0          0       None        NaT       None
# 1     30-50'          1          0       None        NaT       None
# 2       >50'          2          0       None        NaT       None
# 3       None          0          0       None        NaT       None
# 4       None          0          0       None        NaT       None
#
#   citationnu citationda deadtrees3                               photoid  \
# 0       None       None          0                                  None
# 1       None       None       None  f1556c16-78c8-44bf-b6ce-a7ddb5908d96
# 2       None       None       None                                  None
# 3       None       None       None  17322007-d5d1-4568-bde6-00ae169a0bbf
# 4       None       None       None  50114b4c-e04a-4054-bd54-5a7dbca535af
#
#   photoid_ca  le100numbe  inspecti_2 coredatafl partner_di principal_  \
# 0       None         0.0         0.0       None       None       None
# 1       None         0.0         0.0       None       None       None
# 2       None         0.0         0.0       None       None       None
# 3       None         0.0         0.0       None       None       None
# 4       None         0.0         0.0       None       None       None
#
#   firescopei responsibi  yearbuilt siteaddres  numberofst appenddate  \
# 0       None       None     2000.0       None         0.0 2019-06-05
# 1       None       None        0.0       None         0.0 2019-05-09
# 2       None       None        0.0       None         0.0 2019-05-09
# 3       None       None        0.0       None         0.0 2019-05-09
# 4       None       None     2002.0       None         0.0 2019-05-08
#
#   editstatus createddat createdby editeddate editedby textfield1 textfield2  \
# 0       None       None      None       None     None       None       None
# 1       None       None      None       None     None       None       None
# 2       None       None      None       None     None       None       None
# 3       None       None      None       None     None       None       None
# 4       None       None      None       None     None       None       None
#
#    numberfiel  numberfi_1 core_with_       Date          apn  \
# 0         0.0         0.0       None 2019-06-05  141-010-040
# 1         0.0         0.0       None 2019-05-09  135-310-022
# 2         0.0         0.0       None 2019-05-09  135-310-075
# 3         0.0         0.0       None 2019-05-09  135-310-075
# 4         0.0         0.0       None 2019-12-17  135-310-042
#
#                                             geometry
# 0  POLYGON ((-2813.179 -371821.557, -2813.179 -37...
# 1  POLYGON ((-8368.416 -370860.259, -8475.394 -37...
# 2  POLYGON ((-8253.618 -371073.707, -8136.129 -37...
# 3  POLYGON ((-8201.866 -370989.432, -8201.866 -37...
# 4  POLYGON ((-7966.144 -370818.558, -7966.144 -37...

# %%
insp_23.head()
# Out:
#                              fulcrum_id          created_at  \
# 0  48c58877-f0ce-438d-ac87-6434a2c15fe8 2022-02-13 16:00:00
# 1  48c58877-f0ce-438d-ac87-6434a2c15fe8 2022-02-13 16:00:00
# 2  48c58877-f0ce-438d-ac87-6434a2c15fe8 2022-02-13 16:00:00
# 3  48c58877-f0ce-438d-ac87-6434a2c15fe8 2022-02-13 16:00:00
# 4  48c58877-f0ce-438d-ac87-6434a2c15fe8 2022-02-13 16:00:00
#
#            updated_at       created_by       updated_by   system_created_at  \
# 0 2023-06-05 17:00:00  gis@sbcfire.com  gis@sbcfire.com 2022-02-14 10:44:17
# 1 2023-06-05 17:00:00  gis@sbcfire.com  gis@sbcfire.com 2022-02-14 10:44:17
# 2 2023-06-05 17:00:00  gis@sbcfire.com  gis@sbcfire.com 2022-02-14 10:44:17
# 3 2023-06-05 17:00:00  gis@sbcfire.com  gis@sbcfire.com 2022-02-14 10:44:17
# 4 2023-06-05 17:00:00  gis@sbcfire.com  gis@sbcfire.com 2022-02-14 10:44:17
#
#     system_updated_at  version     status project assigned_to   latitude  \
# 0 2023-12-06 08:54:05       13  Compliant    None        None  34.461625
# 1 2023-12-06 08:54:05       13  Compliant    None        None  34.461625
# 2 2023-12-06 08:54:05       13  Compliant    None        None  34.461625
# 3 2023-12-06 08:54:05       13  Compliant    None        None  34.461625
# 4 2023-12-06 08:54:05       13  Compliant    None        None  34.461625
#
#     longitude                        report_title globalid  keyid  \
# 0 -119.772555  Defensible Space Inspection Report     None    0.0
# 1 -119.772555  Defensible Space Inspection Report     None    0.0
# 2 -119.772555  Defensible Space Inspection Report     None    0.0
# 3 -119.772555  Defensible Space Inspection Report     None    0.0
# 4 -119.772555  Defensible Space Inspection Report     None    0.0
#
#   propertystatus inspectionstatus inspectorfirstname inspectorlastname  \
# 0           None             None               None              None
# 1           None             None               None              None
# 2           None             None               None              None
# 3           None             None               None              None
# 4           None             None               None              None
#
#   prevention_inspectorfirstname prevention_inspectorfirstname_other  \
# 0                     Charlotte                                None
# 1                     Charlotte                                None
# 2                     Charlotte                                None
# 3                     Charlotte                                None
# 4                     Charlotte                                None
#
#   prevention_inspectorlastname prevention_inspectorlastname_other  \
# 0                     Endicott                               None
# 1                     Endicott                               None
# 2                     Endicott                               None
# 3                     Endicott                               None
# 4                     Endicott                               None
#
#   inspectorposition inspectiondate_calculate            addressvisible  \
# 0               DSI               2023-06-05  Yes - Without Reflective
# 1               DSI               2023-06-05  Yes - Without Reflective
# 2               DSI               2023-06-05  Yes - Without Reflective
# 3               DSI               2023-06-05  Yes - Without Reflective
# 4               DSI               2023-06-05  Yes - Without Reflective
#
#   address_sub_thoroughfare address_thoroughfare address_suite  \
# 0                     4440     Shadow Hills Cir          None
# 1                     4440     Shadow Hills Cir          None
# 2                     4440     Shadow Hills Cir          None
# 3                     4440     Shadow Hills Cir          None
# 4                     4440     Shadow Hills Cir          None
#
#   address_locality address_sub_admin_area address_admin_area  \
# 0    Santa Barbara          Santa Barbara                 CA
# 1    Santa Barbara          Santa Barbara                 CA
# 2    Santa Barbara          Santa Barbara                 CA
# 3    Santa Barbara          Santa Barbara                 CA
# 4    Santa Barbara          Santa Barbara                 CA
#
#   address_postal_code address_country  \
# 0               93105              US
# 1               93105              US
# 2               93105              US
# 3               93105              US
# 4               93105              US
#
#                                         address_full calfireunit county  \
# 0  4440 Shadow Hills Cir Santa Barbara Santa Barb...         SBC    SBA
# 1  4440 Shadow Hills Cir Santa Barbara Santa Barb...         SBC    SBA
# 2  4440 Shadow Hills Cir Santa Barbara Santa Barb...         SBC    SBA
# 3  4440 Shadow Hills Cir Santa Barbara Santa Barb...         SBC    SBA
# 4  4440 Shadow Hills Cir Santa Barbara Santa Barb...         SBC    SBA
#
#               community community_other battalion  enginenumber stationname  \
# 0  San Marcos Foothills            None         1           NaN          13
# 1  San Marcos Foothills            None         1           NaN          13
# 2  San Marcos Foothills            None         1           NaN          13
# 3  San Marcos Foothills            None         1           NaN          13
# 4  San Marcos Foothills            None         1           NaN          13
#
#   shift shift_julian accessegress occupanthome deliverynotificationmethod  \
# 0     A          157          Yes           No                     Mailed
# 1     A          157          Yes           No                     Mailed
# 2     A          157          Yes           No                     Mailed
# 3     A          157          Yes           No                     Mailed
# 4     A          157          Yes           No                     Mailed
#
#   inspectionhours a_removebranchesfromstovepipe b_removeleavesneedlesveg  \
# 0              15                          None                     None
# 1              15                          None                     None
# 2              15                          None                     None
# 3              15                          None                     None
# 4              15                          None                     None
#
#   c_removedeaddyingtrees d_removedeaddyinggrassplants  \
# 0                   None                         None
# 1                   None                         None
# 2                   None                         None
# 3                   None                         None
# 4                   None                         None
#
#   e_removeflammablegroundcover f_removeflammablevegetation  \
# 0                         None                        None
# 1                         None                        None
# 2                         None                        None
# 3                         None                        None
# 4                         None                        None
#
#   g_relocateexposedwoodpiles h_cutannualgrassesforbs  \
# 0                       None                    None
# 1                       None                    None
# 2                       None                    None
# 3                       None                    None
# 4                       None                    None
#
#   i_removefuelsusingctguidelines j_exposedwoodpiles  \
# 0                           None               None
# 1                           None               None
# 2                           None               None
# 3                           None               None
# 4                           None               None
#
#   k_removedeaddyingwoodyfuels l_removelogstumpsembeddedsoil  \
# 0                        None                          None
# 1                        None                          None
# 2                        None                          None
# 3                        None                          None
# 4                        None                          None
#
#   m_outbuildingsliquidpropanegas n_displayaddresscontrasting  \
# 0                           None                        None
# 1                           None                        None
# 2                           None                        None
# 3                           None                        None
# 4                           None                        None
#
#   o_stovepipemetalscreenopenings recommendclearvegetation waterstora  \
# 0                           None                     None        yes
# 1                           None                     None        yes
# 2                           None                     None        yes
# 3                           None                     None        yes
# 4                           None                     None        yes
#
#                              water_source can_engine_access_water_source  \
# 0  Hydrant- Municipal/Public Water Supply                            yes
# 1  Hydrant- Municipal/Public Water Supply                            yes
# 2  Hydrant- Municipal/Public Water Supply                            yes
# 3  Hydrant- Municipal/Public Water Supply                            yes
# 4  Hydrant- Municipal/Public Water Supply                            yes
#
#   water_storage_size_stored_water_on_individual_parcels_only water_comments  \
# 0                                               None                   None
# 1                                               None                   None
# 2                                               None                   None
# 3                                               None                   None
# 4                                               None                   None
#
#                         structuretype structurehabitable roofconstruction  \
# 0  Multi Family Residence Multi Story          Habitable             Tile
# 1  Multi Family Residence Multi Story          Habitable             Tile
# 2  Multi Family Residence Multi Story          Habitable             Tile
# 3  Multi Family Residence Multi Story          Habitable             Tile
# 4  Multi Family Residence Multi Story          Habitable             Tile
#
#       eaves           ventscreen exteriorsiding   windowpane  \
# 0  Enclosed  Mesh Screen <= 1/8"          Other  Single Pane
# 1  Enclosed  Mesh Screen <= 1/8"          Other  Single Pane
# 2  Enclosed  Mesh Screen <= 1/8"          Other  Single Pane
# 3  Enclosed  Mesh Screen <= 1/8"          Other  Single Pane
# 4  Enclosed  Mesh Screen <= 1/8"          Other  Single Pane
#
#      deckporchgrade deckporchelevated patiocovercarport  \
# 0  Masonry/Concrete  Masonry/Concrete   Non Combustible
# 1  Masonry/Concrete  Masonry/Concrete   Non Combustible
# 2  Masonry/Concrete  Masonry/Concrete   Non Combustible
# 3  Masonry/Concrete  Masonry/Concrete   Non Combustible
# 4  Masonry/Concrete  Masonry/Concrete   Non Combustible
#
#   fenceattachedtostructure propanetankdistance utilitymiscstructuredistance  \
# 0                 No Fence      Not Applicable                         None
# 1                 No Fence      Not Applicable                         None
# 2                 No Fence      Not Applicable                         None
# 3                 No Fence      Not Applicable                         None
# 4                 No Fence      Not Applicable                         None
#
#   utilitymiscstucturecount nonhabitableoutbuildings escalatetocoordinator  \
# 0                        0                        0                  None
# 1                        0                        0                  None
# 2                        0                        0                  None
# 3                        0                        0                  None
# 4                        0                        0                  None
#
#   reinspectiondate citationnumber  \
# 0              NaT           None
# 1              NaT           None
# 2              NaT           None
# 3              NaT           None
# 4              NaT           None
#
#    number_of_dead_trees_within_300_ft_of_residence gatecode comments  \
# 0                                                0     None     None
# 1                                                0     None     None
# 2                                                0     None     None
# 3                                                0     None     None
# 4                                                0     None     None
#
#                                              photoid photoid_caption  \
# 0  eb994fe9-6273-444c-95b7-c3633b0876f5,de1dc62a-...              ,,
# 1  eb994fe9-6273-444c-95b7-c3633b0876f5,de1dc62a-...              ,,
# 2  eb994fe9-6273-444c-95b7-c3633b0876f5,de1dc62a-...              ,,
# 3  eb994fe9-6273-444c-95b7-c3633b0876f5,de1dc62a-...              ,,
# 4  eb994fe9-6273-444c-95b7-c3633b0876f5,de1dc62a-...              ,,
#
#                                          photoid_url le100number  \
# 0  https://web.fulcrumapp.com/photos/view?photos=...        None
# 1  https://web.fulcrumapp.com/photos/view?photos=...        None
# 2  https://web.fulcrumapp.com/photos/view?photos=...        None
# 3  https://web.fulcrumapp.com/photos/view?photos=...        None
# 4  https://web.fulcrumapp.com/photos/view?photos=...        None
#
#   inspectioncount coredata firescopeid  yearbuilt siteaddress  \
# 0            None     None        None        NaN        None
# 1            None     None        None        NaN        None
# 2            None     None        None        NaN        None
# 3            None     None        None        NaN        None
# 4            None     None        None        NaN        None
#
#   numberofstructures appenddate editstatus calculatedglobalid calculateddate  \
# 0               None       None       None               None           None
# 1               None       None       None               None           None
# 2               None       None       None               None           None
# 3               None       None       None               None           None
# 4               None       None       None               None           None
#
#   calculateduid textfield1 textfield2 numberfield1 numberfield2  \
# 0          None       None       None         None         None
# 1          None       None       None         None         None
# 2          None       None       None         None         None
# 3          None       None       None         None         None
# 4          None       None       None         None         None
#
#   previousyrinspecteddata previousyrinspectionstatus calculatededitor  \
# 0                    None                       None             None
# 1                    None                       None             None
# 2                    None                       None             None
# 3                    None                       None             None
# 4                    None                       None             None
#
#   calculatededitdate creationdate   editdate creator editor       Date  \
# 0               None   2022-02-14 2022-02-14    None   None 2023-06-05
# 1               None   2022-02-14 2022-02-14    None   None 2023-06-05
# 2               None   2022-02-14 2022-02-14    None   None 2023-06-05
# 3               None   2022-02-14 2022-02-14    None   None 2023-06-05
# 4               None   2022-02-14 2022-02-14    None   None 2023-06-05
#
#            apn                                           geometry
# 0  059-380-022  MULTIPOLYGON (((20815.284 -394983.12, 20815.28...
# 1  059-400-008  POLYGON ((20894.506 -394935.534, 20893.716 -39...
# 2  059-400-003  POLYGON ((20894.506 -394935.534, 20893.808 -39...
# 3  059-400-001  POLYGON ((20874.822 -394919.585, 20875.482 -39...
# 4  059-400-006  POLYGON ((20874.822 -394919.585, 20875.482 -39...

# %%
colnames_23 = {
    "system_created_at": "system_cre",
    "address_suite": "address_su",
    "address_thoroughfare": "address_th",
    "address_locality": "address_lo",
    "address_sub_admin_area": "address__2",
    "address_postal_code": "address_po",
    "address_full": "address_fu",
    "inspectiondate_calculate": "inspection",
    "structuretype": "structuret",
    "address_admin_area": "address_ad",
    "address_country": "address_co"
}

insp_23 = insp_23.rename(columns=colnames_23)

# %%
insp_19["year"] = 2019
insp_20["year"] = 2020
insp_21["year"] = 2021
insp_22["year"] = 2022
insp_23["year"] = 2023

# %%
len(insp_19.columns)
# Out:
# 107

# %%
len(insp_23.columns)
# Out:
# 122

# %%
inspections = pd.concat(
    [insp_19, insp_20, insp_21, insp_22, insp_23], axis=0, ignore_index=True
)
# Out:
# /tmp/ipykernel_62920/219999832.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   inspections = pd.concat(

# %%
# converting 'system_cre' column to display single days, instead of days and times
inspections["system_cre"] = pd.to_datetime(inspections["system_cre"]).dt.date

# %%
# Some dates in the 'inspection' column have the format '2023-08-22 00:00:00'.
# This chunk is to remove the occurrences of '00:00:00' and remove trailing whitespace.

inspections["inspection"] = (
    inspections["inspection"]
    .astype(str)
    .str.replace(" 00:00:00", "", regex=False)
    .str.strip()
)

# %%
# Fixing CRS to 3310, Albers

inspections = inspections.to_crs(epsg=3310)

print(inspections.crs)
# Out:
# EPSG:3310

# %%
# adding address_id to be unique for every unique inspection
inspections["inspection_id"] = np.arange(1, len(inspections) + 1)

# %%
inspections.inspection_id
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 89352    89353
# 89353    89354
# 89354    89355
# 89355    89356
# 89356    89357
# Name: inspection_id, Length: 89357, dtype: int64

# %%
# inspections.to_file(
#     "/capstone/wildfire_prep/data/PUZZLE_PIECES/inspections_master.geojson",
#     driver="GeoJSON",
# )

# %%
inspections.status.value_counts()
# Out:
# status
# Compliant        88902
# Non-Compliant      455
# Name: count, dtype: int64

# %% [markdown]
# Investigation into differences in rows between buffer_geometries and Leilanie's dataset

# %%
# loading in inspections_with_buildings .geojsons

inspections_with_buildings_2019 = gpd.read_file(
    "/capstone/wildfire_prep/data/joined_inspections_buildings/inspections_with_buildings_2019.geojson"
)
inspections_with_buildings_2020 = gpd.read_file(
    "/capstone/wildfire_prep/data/joined_inspections_buildings/inspections_with_buildings_2020.geojson"
)
inspections_with_buildings_2021 = gpd.read_file(
    "/capstone/wildfire_prep/data/joined_inspections_buildings/inspections_with_buildings_2021.geojson"
)
inspections_with_buildings_2022 = gpd.read_file(
    "/capstone/wildfire_prep/data/joined_inspections_buildings/inspections_with_buildings_2022.geojson"
)
inspections_with_buildings_2023 = gpd.read_file(
    "/capstone/wildfire_prep/data/joined_inspections_buildings/inspections_with_buildings_2023.geojson"
)

# %%
inspections_with_buildings_length = (
    len(inspections_with_buildings_2019)
    + len(inspections_with_buildings_2020)
    + len(inspections_with_buildings_2021)
    + len(inspections_with_buildings_2022)
    + len(inspections_with_buildings_2023)
)

inspections_with_buildings_length
# Out:
# 67580

# %%
# length of buffer geometries combined, loaded at the top

buffer_geometries_length
# Out:
# 89357

# %%
inspections_buffered_buildings_all = gpd.read_file(
    "/capstone/wildfire_prep/data/joined_inspections_parcels/inspections_buffered_buildings_all.geojson"
)
print(len(inspections_buffered_buildings_all))
# Out:
# 88376

# %%
inspections_parcels_all = gpd.read_file(
    "/capstone/wildfire_prep/data/joined_inspections_parcels/inspections_parcels_all.geojson"
)
print(len(inspections_parcels_all))
# Out:
# 68352

# %%
buffered_buildings_2022 = gpd.read_file(
    "/capstone/wildfire_prep/data/joined_inspections_parcels/buffered_buildings_2022.geojson"
)
print(len(buffered_buildings_2022))
print(len(inspections_with_buildings_2022))
# Out:
# 9035
# 13642

# %%
inspections_2019 = gpd.read_file(
    "/capstone/wildfire_prep/data/inspections_data/cleaned_status/inspections_2019.geojson"
)
inspections_2020 = gpd.read_file(
    "/capstone/wildfire_prep/data/inspections_data/cleaned_status/inspections_2020.geojson"
)
inspections_2021 = gpd.read_file(
    "/capstone/wildfire_prep/data/inspections_data/cleaned_status/inspections_2021.geojson"
)
inspections_2022 = gpd.read_file(
    "/capstone/wildfire_prep/data/inspections_data/cleaned_status/inspections_2022.geojson"
)
inspections_2023 = gpd.read_file(
    "/capstone/wildfire_prep/data/inspections_data/cleaned_status/inspections_2023.geojson"
)

# %%
inspections_clean_status_length = (
    len(inspections_2019)
    + len(inspections_2020)
    + len(inspections_2021)
    + len(inspections_2022)
    + len(inspections_2023)
)

inspections_clean_status_length
# Out:
# 67580

# %%
training_geometries_2019 = gpd.read_file(
    "/capstone/wildfire_prep/data/training_geometries/training_geometries_2019.geojson"
)
training_geometries_2020 = gpd.read_file(
    "/capstone/wildfire_prep/data/training_geometries/training_geometries_2020.geojson"
)
training_geometries_2021 = gpd.read_file(
    "/capstone/wildfire_prep/data/training_geometries/training_geometries_2021.geojson"
)
training_geometries_2022 = gpd.read_file(
    "/capstone/wildfire_prep/data/training_geometries/training_geometries_2022.geojson"
)
training_geometries_2023 = gpd.read_file(
    "/capstone/wildfire_prep/data/training_geometries/training_geometries_2023.geojson"
)

training_geometries_combined_length = (
    len(training_geometries_2019)
    + len(training_geometries_2020)
    + len(training_geometries_2021)
    + len(training_geometries_2022)
    + len(training_geometries_2023)
)

training_geometries_combined_length
# Out:
# 67580

# %%
print(f"cleaned_status: Inspections files combined length: {inspections_clean_status_length}")
print(
    f"joined_inspections_buildings: Inspections with buildings files combined length: {inspections_with_buildings_length}"
)
print(
    f"joined_inspections_parcels: Inspections with parcels length: {len(inspections_parcels_all)}"
)
print(
    f"joined_inspections_parcels: Inspections with buffered buildings all length: {len(inspections_buffered_buildings_all)}"
)
print(
    f"buffer_geometries: Inspections with Buffered Geometries files combined length: {buffer_geometries_length}"
)
print(f"training_geometries: Training geometries combined length: {training_geometries_combined_length}")
# Out:
# cleaned_status: Inspections files combined length: 67580
# joined_inspections_buildings: Inspections with buildings files combined length: 67580
# joined_inspections_parcels: Inspections with parcels length: 68352
# joined_inspections_parcels: Inspections with buffered buildings all length: 88376
# buffer_geometries: Inspections with Buffered Geometries files combined length: 89357
# training_geometries: Training geometries combined length: 67580

# %%
training_geometries_2019
# Out:
#                                  fulcrum_id   apn       Date  year  month  \
# 0      d9a4d031-d16d-4c84-b32c-f3fcd7d945df  None 2019-06-05  2019      6
# 1      7f9b6d98-548d-4b94-97c6-82cbddf84d99  None 2019-05-09  2019      5
# 2      03afdf39-173a-4f02-bfdc-e0725e554959  None 2019-05-09  2019      5
# 3      941e29b0-6cd3-4c7e-a919-b8f2410b4a2b  None 2019-05-09  2019      5
# 4      abe890ba-3269-4ef6-84d7-4a9b6bfd717e  None 2019-12-17  2019     12
# ...                                     ...   ...        ...   ...    ...
# 14670                                  None  None 2019-06-14  2019      6
# 14671                                  None  None 2019-08-01  2019      8
# 14672                                  None  None 2019-08-01  2019      8
# 14673                                  None  None 2019-06-18  2019      6
# 14674                                  None  None 2019-06-25  2019      6
#
#               status                                           geometry
# 0          Compliant  POLYGON ((-2892.357 -371905.217, -2813.179 -37...
# 1          Compliant  POLYGON ((-8475.394 -370860.259, -8368.416 -37...
# 2          Compliant  POLYGON ((-8253.618 -371183.727, -8136.129 -37...
# 3          Compliant  POLYGON ((-8201.866 -370989.432, -8091.086 -37...
# 4          Compliant  POLYGON ((-8065.883 -370931.624, -7966.144 -37...
# ...              ...                                                ...
# 14670      Compliant  POLYGON ((30822.983 -396671.555, 30900.797 -39...
# 14671      Compliant  POLYGON ((30894.968 -396708.273, 30972.782 -39...
# 14672  Non-Compliant  POLYGON ((32892.059 -396994.879, 32969.873 -39...
# 14673      Compliant  POLYGON ((31869.591 -396830.827, 31947.405 -39...
# 14674      Compliant  POLYGON ((33528.875 -397648.221, 33606.689 -39...
#
# [14675 rows x 7 columns]
