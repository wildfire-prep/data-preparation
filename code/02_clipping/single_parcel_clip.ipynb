# %%
import os
import sys
import numpy as np
import pandas as pd
import geopandas as gpd

import seaborn as sns
import matplotlib.pyplot as plt

sys.path.append("../utils")

import config

pd.set_option("display.max_columns", None)

# %%
# Import inspections data for 2022

def read_geojson_with_geopandas(file_path):
        gdf = gpd.read_file(file_path)
        return gdf

file_path = "/capstone/wildfire_prep/data/joined_inspections_parcels/joined_2022.geojson"
inspections_2022 = read_geojson_with_geopandas(file_path)
inspections_2022.head(101)
# Out:
#         apn_left   layer                situs1                   situs2  \
# 0    069-240-018  Ground  1450 CAMINO MANADERO  SANTA BARBARA, CA 93111
# 1    069-251-004  Ground    1475 CAMINO MELENO  SANTA BARBARA, CA 93111
# 2    135-040-043  Ground     2396 N REFUGIO RD     SANTA YNEZ, CA 93460
# 3    135-040-043  Ground     2396 N REFUGIO RD     SANTA YNEZ, CA 93460
# 4    135-040-043  Ground     2396 N REFUGIO RD     SANTA YNEZ, CA 93460
# ..           ...     ...                   ...                      ...
# 96   153-160-023  Ground  2720 PAINTED CAVE RD  SANTA BARBARA, CA 93105
# 97   153-160-023  Ground  2720 PAINTED CAVE RD  SANTA BARBARA, CA 93105
# 98   153-160-023  Ground  2720 PAINTED CAVE RD  SANTA BARBARA, CA 93105
# 99   153-160-023  Ground  2720 PAINTED CAVE RD  SANTA BARBARA, CA 93105
# 100  153-160-023  Ground  2720 PAINTED CAVE RD  SANTA BARBARA, CA 93105
#
#      acreage                            landuse usecode     tra      docnum  \
# ...

# %%
parcel = inspections_2022.loc[100]
parcel.head()
# Out:
# apn_left                153-160-023
# layer                        Ground
# situs1         2720 PAINTED CAVE RD
# situs2      SANTA BARBARA, CA 93105
# acreage                        40.0
# Name: 100, dtype: object

# %%
scene =
